# %% [markdown]
# ### SQL

# %%
# !pip install mysql
# Out:
# Requirement already satisfied: mysql in C:\Users\KITTU-PALKIN\OneDrive\Documents\Rupahli\GUVI\AIML\aiml_new\Lib\site-packages (0.0.3)
# Requirement already satisfied: mysqlclient in C:\Users\KITTU-PALKIN\OneDrive\Documents\Rupahli\GUVI\AIML\aiml_new\Lib\site-packages (from mysql) (2.2.8)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall mysql
# !pip install mysql-connector-python
# Out:
# ^C
# Requirement already satisfied: mysql-connector-python in C:\Users\KITTU-PALKIN\OneDrive\Documents\Rupahli\GUVI\AIML\aiml_new\Lib\site-packages (9.7.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Samsung11$",
    database="IntelAIML"

)

connection

# %%
import mysql.connector
import json 

with open ("connection.json",mode="r+") as tf:
    config=  json.load(tf)

connection = mysql.connector.connect(
    host=config['host'],
    user=config['user'],
    password=config['password'],
    database=config['database']

)

connection

# %%
import mysql.connector
import json 

with open ("connection.json",mode="r+") as tf:
    config=  json.load(tf)

connection = mysql.connector.connect(
    host=config['host'],
    user=config['user'],
    password=config['password']

)

cursor = connection.cursor()
cursor

#query = "create database IntelAIML_viaPython" # create database using python

#cursor.execute(query)

# %%
query = "use IntelAIML_viaPython"

cursor.execute(query)

# %%
query = "create table staff_1 (emp_id int auto_increment primary key,name varchar(60),salayr float)"

cursor.execute(query)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\KITTU-PALKIN\OneDrive\Documents\Rupahli\GUVI\AIML\aiml_new\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'staff_1' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[43], line 3
#       1 query = "create table staff_1 (emp_id int auto_increment primary key,name varchar(60),salayr float)"
#       2
# ----> 3 cursor.execute(query)
#
# File c:\Users\KITTU-PALKIN\OneDrive\Documents\Rupahli\GUVI\AIML\aiml_new\Lib\site-packages\mysql\connector\cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File c:\Users\KITTU-PALKIN\OneDrive\Documents\Rupahli\GUVI\AIML\aiml_new\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\KITTU-PALKIN\OneDrive\Documents\Rupahli\GUVI\AIML\aiml_new\Lib\site-packages\mysql\connector\connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# ProgrammingError: 1050 (42S01): Table 'staff_1' already exists

# %%
query = "SELECT * FROM intelaiml_viapython.staff"

cursor.execute(query)

#type(cursor.execute(query))

for x in cursor:
    print(x)
