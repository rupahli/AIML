# %%
import re

text= "The rain in Spain stays mainly in the plain."

result = re.match("The", text)
search_result = re.search("rain", text) # Output: <re.Match object; span=(4, 8), match='rain'>   
search_all_result = re.findall("in", text) # Output: ['in', 'in', 'in', 'in', 'in', 'in']


print(result)
print(search_result)
print(search_all_result)
# Out:
# <re.Match object; span=(0, 3), match='The'>
# <re.Match object; span=(4, 8), match='rain'>
# ['in', 'in', 'in', 'in', 'in', 'in']

# %%
import re

text= "T1122323  k2jkj jl j12323 $  #  @ ! lk123 1klj32lkjl12j3"
 
search_all_result = re.findall(r"\S+", text) 

print(search_all_result) # Output: ['1122323', '2', '12323', '123', '1', '32', '12']
# Out:
# ['T1122323', 'k2jkj', 'jl', 'j12323', '$', '#', '@', '!', 'lk123', '1klj32lkjl12j3']

# %%
text= "color colour"
search_result = re.findall(r"colou?r", text) # Output: <re.Match object; span=(0, 5), match='color'>
print(search_result)
# Out:
# ['color', 'colour']

# %%
email="abcd.wewe@gmail.com"
search_result = re.findall(r"\w+\.+\w+@+\w+\.\w+", email)
print(search_result)
# Out:
# ['abcd.wewe@gmail.com']

# %%
email="abwewe.gmail.com"
search_result = re.findall(r"\w+\.+\w+@+\w+\.\w+", email)
print(search_result)
# Out:
# []

# %%
number_plate = "AB12AB1234"
search_result = re.findall(r"[A-Z]{2}+\d{2}+[A-Z]{2}+\d{4}", number_plate)

print(search_result)
# Out:
# []

# %%
number_plate = "0B12AB1234"
search_result = re.findall(r"\w{2}+\d{2}+[A-Z]{2}+\d{4}", number_plate)

print(search_result)
# Out:
# ['0B12AB1234']

# %%
import random

data = ["apple", "banana", "cherry", "date", "elderberry"]
random_item = random.choice(data)
print(random_item)
random_number = random.randint(1, 100)
print(random_number)

random_shuffle = random.shuffle(data)
print(data)
# Out:
# apple
# 74
# ['elderberry', 'date', 'apple', 'banana', 'cherry']

# %%
import os

os.getcwd()
os.listdir()
os.mkdir("new_folder")

# %%
age = int(input("Enter your age: "))
if age < 10:
    raise ValueError("Age must be at least 10.")
else:
    print("Valid Age")
# Out:
# Valid Age

# %%
import re

phno = input("Enter your phone number: ")
if re.match(r"\d{10}$", phno):
    print("Valid phone number")
else:
    raise ValueError("Invalid phone number. Please enter a 10-digit number.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 7
#       3 phno = input("Enter your phone number: ")
#       4 if re.match(r"\d{10}$", phno):
#       5     print("Valid phone number")
#       6 else:
# ----> 7     raise ValueError("Invalid phone number. Please enter a 10-digit number.")
#       8
#
# ValueError: Invalid phone number. Please enter a 10-digit number.
