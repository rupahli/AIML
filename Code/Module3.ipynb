# %% [markdown]
# # 16th May Session

# %%
S = input()

# %%
nm = 5+3j
print(type(nm),nm.real,nm.imag)
# Out:
# <class 'complex'> 5.0 3.0

# %%
nm = 5.5+3.4j
print(type(nm),nm.real,nm.imag)
# Out:
# <class 'complex'> 5.5 3.4

# %%
print(1%2)
# Out:
# 1

# %%
print(4%2)
# Out:
# 0

# %%
N=int(input())
if N%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
num=[12,13,15,17,19]
sum=0
for i in range(len(num)):
    sum+=num[i]
print(sum)
# Out:
# 76

# %%
N=int(input())
f=1
for i in range(1,N+1):
    f=f*i
print(f)
# Out:
# 120

# %%
N=input()
n=0
sum=0
for n in N:
    sum=sum+int(n)
    
print(sum  )
x= len(N)

while x>0:
    sum=0
    for n in N:
        sum=sum+int(n)
    x=x-1

print(sum)
# Out:
# 15
# 15

# %%
def tax_calculation(income):
    
    return income*.02

income=int(input())
print("tax cut is:", tax_calculation(income))
# Out:
# tax cut is: 246.9

# %%
def multi_function(a):
        return(a*a)

a=int(input())
for i in range(1,a):
    if multi_function(i) < a:
          print(multi_function(i))
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
N = int(input())
num = input()
K="0"
res = []
print("num.count('0')..",num.count('0'))
first=num.find(K)
print("first...",first)
if num.count('0')>1:
    
    for i in range(N):
        print("num...",num)
        first=num.find('0')
        print("first...",first)
        newnum = num[first+1:] 
        print("newnum...",newnum)
        last=newnum.find('0')
        print("last...",last)
        res.append(num[first+1:last])
        print("res...",res)
        num=newnum
else:
    print("-1")
# Out:
# num.count('0').. 3
# first... 6
# num... 1 1 1 0 1 0 1 1 0 1
# first... 6
# newnum...  1 0 1 1 0 1
# last... 3
# res... ['']
# num...  1 0 1 1 0 1
# first... 3
# newnum...  1 1 0 1
# last... 5
# res... ['', ' ']
# num...  1 1 0 1
# first... 5
# newnum...  1
# last... -1
# res... ['', ' ', ' ']
# num...  1
# first... -1
# newnum...  1
# last... -1
# res... ['', ' ', ' ', ' ']
# num...  1
# first... -1
# newnum...  1
# last... -1
# res... ['', ' ', ' ', ' ', ' ']
# num...  1
# first... -1
# newnum...  1
# last... -1
# res... ['', ' ', ' ', ' ', ' ', ' ']
# num...  1
# first... -1
# newnum...  1
# last... -1
# res... ['', ' ', ' ', ' ', ' ', ' ', ' ']
# num...  1
# first... -1
# newnum...  1
# last... -1
# res... ['', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# num...  1
# first... -1
# newnum...  1
# last... -1
# res... ['', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# num...  1
# first... -1
# newnum...  1
# last... -1
# res... ['', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
import math 
math.factorial(5)
# Out:
# 120

# %%
math.gcd(12,15)
# Out:
# 3

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.sqrt(19)
# Out:
# 4.358898943540674

# %%
math.isqrt(19)
# Out:
# 4

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.ceil(2.3)
# Out:
# 3

# %%
math.floor(2.3)
# Out:
# 2

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.trunc(2.8)
# Out:
# 2

# %%
math.dist((1,2),(3,4))
# Out:
# 2.8284271247461903

# %%
math.prod([1,2,3,4])
# Out:
# 24

# %%
math.inf
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
math.remainder(20, 3)
# Out:
# -1.0

# %%
math.fmod(20, 3)
# Out:
# 2.0

# %%
def get_tax(income):
    tax=0
    if income > 3000000:
        tax = income * 0.03
    elif income > 2000000:
        tax = income * 0.02
    else:
        tax = 0

    return tax

# %%
get_tax(2500000)
# Out:
# 50000.0

# %%
get_tax('abc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 get_tax('abc')
#
# Cell In[75], line 3, in get_tax(income)
#       1 def get_tax(income):
#       2     tax=0
# ----> 3     if income > 3000000:
#       4         tax = income * 0.03
#       5     elif income > 2000000:
#       6         tax = income * 0.02
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
try:
    num=int(input())
    print(10/num)
except Exception as e:
    print("Error:",e)
    print("Error type :",type(e).__name__)

except ValueError:
    print("Error: Invalid input. Please enter a valid integer.")
except:
    print("Error: Division by zero")
finally:
    print("This will always execute")
# Out:
# Error: invalid literal for int() with base 10: 'asddasdsa'
# Error type : ValueError
# This will always execute
